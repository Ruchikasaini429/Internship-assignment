# %%
# Write a Python function to find the maximum of three numbers
def max_of_three(a, b, c):
    return max(a, b, c)
num1 = 10
num2 = 20
num3 = 15
result = max_of_three(num1, num2, num3)
print(f"The maximum of {num1}, {num2}, and {num3} is: {result}")
# Out:
# The maximum of 10, 20, and 15 is: 20

# %%
# Write a Python function that takes a list and returns a new list with distinct elements from the first list.

def distinct_elements(input_list):
    return list(set(input_list))
my_list = [1, 2, 3, 4, 2, 3, 5]
result = distinct_elements(my_list)
print(f"The distinct elements from the list {my_list} are: {result}")
# Out:
# The distinct elements from the list [1, 2, 3, 4, 2, 3, 5] are: [1, 2, 3, 4, 5]

# %%
#Write a Python function to multiply all the numbers in a list.
def multiply_list(numbers):
    result = 1
    for num in numbers:
        result *= num
    return result
input_numbers = [2, 3, 4]
product = multiply_list(input_numbers)
print(f"The product of the numbers in the list {input_numbers} is: {product}")
# Out:
# The product of the numbers in the list [2, 3, 4] is: 24

# %%
# Write a Python function to calculate the factorial of a number (a non-negative integer). The function accepts the number as an argument.

def factorial(n):
    if n < 0:
        return "Factorial is not defined for negative numbers."
    elif n == 0 or n == 1:
        return 1
    else:
        result = 1
        for i in range(2, n + 1):
            result *= i
        return result
number = 5
result = factorial(number)
print(f"The factorial of {number} is: {result}")
# Out:
# The factorial of 5 is: 120

# %%
# Write a Python program to reverse a string.
def reverse_string(s):
    return s[::-1]  
input_string = "Hello, World!"
reversed_string = reverse_string(input_string)  
print(f"The reverse of the string '{input_string}' is: '{reversed_string}'")
# Out:
# The reverse of the string 'Hello, World!' is: '!dlroW ,olleH'

# %%
#Write a Python function to check whether a number falls within a given range.

def inside_range(num, start, end):
    return start <= num <= end
number = 5
start_range = 1
end_range = 10
result = inside_range(number, start_range, end_range)
print(f"Is the number {number} inside the range {start_range} to {end_range}? {result}")
# Out:
# Is the number 5 inside the range 1 to 10? True

# %%
#Write a Python function to Print Even Numbers from a Given List

def even_numbers(given_list):
    even_nums = [num for num in given_list if num % 2 == 0]
    return even_nums
input_list = [1, 2, 3, 4, 5, 6,6,8,10,34,56,78,87,66,56,22,33,43,54,65,76,87,98,99]
result = even_numbers(input_list)
print(f"The even numbers from the list {input_list} are: {result}")
# Out:
# The even numbers from the list [1, 2, 3, 4, 5, 6, 6, 8, 10, 34, 56, 78, 87, 66, 56, 22, 33, 43, 54, 65, 76, 87, 98, 99] are: [2, 4, 6, 6, 8, 10, 34, 56, 78, 66, 56, 22, 54, 76, 98]

# %%
#Write a Python function that takes a number as a parameter and checks whether the number is prime or not.

def is_prime(num):
    if num <= 1:
        return False
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            return False
    return True
number = 29
result = is_prime(number)
print(f"Is the number {number} a prime number? {result}")
# Out:
# Is the number 29 a prime number? True

# %%
# Write a Python function that accepts a string and counts the number of upper and lower case letters. 

def count_case(s):
    upper_count = sum(1 for char in s if char.isupper())
    lower_count = sum(1 for char in s if char.islower())
    return upper_count, lower_count
input_string = "Hello, World!"
upper_count, lower_count = count_case(input_string)
print(f"The number of uppercase letters in the string '{input_string}' is: {upper_count}")
print(f"The number of lowercase letters in the string '{input_string}' is: {lower_count}")
# Out:
# The number of uppercase letters in the string 'Hello, World!' is: 2
# The number of lowercase letters in the string 'Hello, World!' is: 8

# %%
#Practise reading, writting, appending data in a file
#writing
file = open("student.txt", "w")

file.write("Name: Ruchika\n")
file.write("Course: Python\n")
file.write("Marks: 95")

file.close()

print("Data written successfully")
# Out:
# Data written successfully

# %%
#appending
# append mode adds new data at the end

file = open("student.txt", "a")

file.write("\nCity: Jaipur")
file.write("\nGrade: A")
file.close()
print("Data appended successfully")
# Out:
# Data appended successfully

# %%
#reading
file = open("student.txt", "r")
data = file.read()
print(data)
file.close()
# Out:
# Name: Ruchika
# Course: Python
# Marks: 95
# City: Jaipur
# Grade: A
# City: Jaipur
# Grade: A
